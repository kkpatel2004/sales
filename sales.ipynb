# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\krupa\OneDrive\Desktop\practice\dataset\sales_data_sample.csv", encoding='ISO-8859-1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df['ADDRESSLINE2'] = pd.to_numeric(df['ADDRESSLINE2'], errors='coerce')
df['ADDRESSLINE2'] = df['ADDRESSLINE2'].fillna(df['ADDRESSLINE2'].mean()) 
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2823
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df['STATE'] = pd.to_numeric(df['STATE'],errors='coerce') # # Convert the 'STATE' column to numeric, coercing non-numeric values to NaN
df['STATE'] = df['STATE'].fillna('Unknown')
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2823
# CITY                   0
# STATE                  0
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
# Fill missing 'POSTALCODE' with '00000' 
df['POSTALCODE'] = df['POSTALCODE'].fillna('00000')
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2823
# CITY                   0
# STATE                  0
# POSTALCODE             0
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
# Fill missing 'TERRITORY' with 'Unknown' or the mode of the column
df['TERRITORY'] = df['TERRITORY'].fillna(df['TERRITORY'].mode()[0])  # or use 'Unknown'
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2823
# CITY                   0
# STATE                  0
# POSTALCODE             0
# COUNTRY                0
# TERRITORY              0
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2        float64
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
# Summary statistics
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP  \
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
# Plot histogram for 'SALES'
#plt.figure(figsize=(8, 6))
#df['SALES'].hist(bins=20, color='skyblue', edgecolor='black')
#plt.title('Distribution of Sales Amount', fontsize=16)
#plt.xlabel('Sales', fontsize=14)
#plt.ylabel('Frequency', fontsize=14)
#plt.grid(False)  # Turn off grid if preferred
#plt.show()


# Define conditions for coloring
low_sales = df['SALES'][df['SALES'] < 300]
medium_sales = df['SALES'][(df['SALES'] >= 300)]
high_sales = df['SALES'][df['SALES'] >= 400]

# Plot histogram with colors
plt.figure(figsize=(8, 6))

# Plot each segment with different colors
plt.hist(low_sales, bins=20, color='lightcoral', edgecolor='black', label='Low Sales (< 300)')
plt.hist(medium_sales, bins=20, color='gold', edgecolor='black', label='Medium Sales (300-399)')
plt.hist(high_sales, bins=20, color='limegreen', edgecolor='black', label='High Sales (>= 400)')

# Add titles and labels
plt.title('Distribution of Sales Amount', fontsize=16)
plt.xlabel('Sales', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(fontsize=12)  # Add legend
plt.grid(False)  # Turn off grid if preferred
plt.show()

# %%
# products generate the highest price
product = df.groupby('PRODUCTLINE')['PRICEEACH'].sum().sort_values(ascending=False).reset_index()
product
# Out:
#         PRODUCTLINE  PRICEEACH
# 0      Classic Cars   84453.70
# 1      Vintage Cars   47435.96
# 2       Motorcycles   27472.19
# 3  Trucks and Buses   26345.91
# 4            Planes   25012.72
# 5             Ships   19622.18
# 6            Trains    5825.41

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x="PRODUCTLINE", y="PRICEEACH", data=product, palette="Blues_d")
plt.title("Top product by price")
plt.xlabel('Product')
plt.ylabel('Price')
for p in ax.patches: 
    ax.annotate(f'{p.get_height():.2f}',  # Display the height of the bar (price)
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Position of the label
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\krupa\AppData\Local\Temp\ipykernel_19372\1227926805.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x="PRODUCTLINE", y="PRICEEACH", data=product, palette="Blues_d")

# %%
# Group by YEAR_ID and sum the SALES to get total sales per year
sales_per_year = df.groupby('YEAR_ID')['SALES'].sum().reset_index()

# Sort the sales in descending order and get top 10
sales_per_year_top10 = sales_per_year.sort_values(by='SALES', ascending=False).head(10)

# Display the top 10 sales per year
sales_per_year_top10
# Out:
#    YEAR_ID       SALES
# 1     2004  4724162.60
# 0     2003  3516979.54
# 2     2005  1791486.71

# %%
# Plotting the top 10 sales per year
plt.figure(figsize=(9, 5))
sns.barplot(x='YEAR_ID', y='SALES', data=sales_per_year_top10, palette='viridis')

# Set the title and labels
plt.title('Top 10 Total Sales per Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\krupa\AppData\Local\Temp\ipykernel_19372\2263929680.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='YEAR_ID', y='SALES', data=sales_per_year_top10, palette='viridis')

# %%
# Plotting the sales per month 
plt.figure(figsize=(9, 5))
ax = sns.barplot(x='MONTH_ID', y='SALES', data=df, palette='inferno')

# Set the title and labels
plt.title('Total Sales per Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)

for p in ax.patches:
    ax.annotate(f'{p.get_height():,.0f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=10, color='black', 
                xytext=(0, 5), textcoords='offset points')
    
# Show the plot
plt.show()
# Out:
# C:\Users\krupa\AppData\Local\Temp\ipykernel_19372\3702268041.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='MONTH_ID', y='SALES', data=df, palette='inferno')

# %%
# Plotting the sales per quter 
plt.figure(figsize=(9, 5))
ax = sns.barplot(x='QTR_ID', y='SALES', data=df, palette='BuGn')

# Set the title and labels
plt.title('Total Sales per QTR', fontsize=14)
plt.xlabel('QTR', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)

for p in ax.patches:
    ax.annotate(f'{p.get_height():,.0f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=10, color='black', 
                xytext=(0, 5), textcoords='offset points')
    
# Show the plot
plt.show()
# Out:
# C:\Users\krupa\AppData\Local\Temp\ipykernel_19372\671247719.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='QTR_ID', y='SALES', data=df, palette='BuGn')

# %%
plt.figure(figsize=(10, 6))

# Create a bar plot to compare sales performance across territories
ax = sns.barplot(x='TERRITORY', y='SALES', data=df, palette='BuPu')

# Set the title and labels
plt.title('Sales Performance by Territory', fontsize=14)
plt.xlabel('Territory', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)

for p in ax.patches:
    ax.annotate(f'{p.get_height():,.0f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=10, color='black', 
                xytext=(0, 5), textcoords='offset points')
# Show the plot
plt.show()
# Out:
# C:\Users\krupa\AppData\Local\Temp\ipykernel_19372\3830849088.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='TERRITORY', y='SALES', data=df, palette='BuPu')

# %%
# Assuming 'df' has a 'DATE' column and 'SALES' column
# Convert 'DATE' to datetime if it's not already in datetime format
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])

# Extract year and quarter from the 'DATE' column
df['Year'] = df['ORDERDATE'].dt.year
df['Quarter'] = df['ORDERDATE'].dt.to_period('Q')

# Group by Year and Quarter and calculate total sales
sales_by_year_quarter = df.groupby(['Year', 'Quarter'])['SALES'].sum().reset_index()

# Create a plot
plt.figure(figsize=(12, 6))

# Plotting the total sales by Year and Quarter
ax = sns.barplot(x='Quarter', y='SALES', hue='Year', data=sales_by_year_quarter, palette='RdYlBu')

# Set the title and labels
plt.title('Total Sales for Each Year and Quarter', fontsize=14)
plt.xlabel('Year and Quarter', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)

for p in ax.patches:
    ax.annotate(f'{p.get_height():,.0f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=10, color='black', 
                xytext=(0, 5), textcoords='offset points')

# Show the plot
plt.show()

# %%
# Assuming df has 'DATE' and 'SALES' columns
# Convert 'DATE' to datetime if it's not already in datetime format
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])

# Extract Year and Month from the 'DATE' column
df['Year'] = df['ORDERDATE'].dt.year
df['Month'] = df['ORDERDATE'].dt.month

# Group by Year and Month and calculate total sales
sales_trend = df.groupby(['Year', 'Month'])['SALES'].sum().reset_index()

# Create a 'Date' column for easier plotting
sales_trend['Date'] = pd.to_datetime(sales_trend[['Year', 'Month']].assign(DAY=1))

# Plotting the trend of sales over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='SALES', data=sales_trend, marker='o', color='b')

# Set the title and labels
plt.title('Sales Trend Over Time (Months/Years)', fontsize=14)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)

# Show the plot
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
customer_sales = df.groupby('CUSTOMERNAME')['SALES'].sum().reset_index()

# Sort the customers by total sales in descending order
customer_sales_sorted = customer_sales.sort_values(by='SALES', ascending=False)

# Display the top N high-value customers (e.g., top 10)
top_customers = customer_sales_sorted.head(10)
print(top_customers)
# Out:
#                     CUSTOMERNAME      SALES
# 33         Euro Shopping Channel  912294.11
# 55  Mini Gifts Distributors Ltd.  654858.06
# 6     Australian Collectors, Co.  200995.41
# 58            Muscle Machine Inc  197736.94
# 44             La Rochelle Gifts  180124.90
# 31       Dragon Souveniers, Ltd.  172989.68
# 45             Land of Toys Inc.  164069.44
# 81     The Sharp Gifts Warehouse  160010.27
# 0                 AV Stores, Co.  157807.81
# 3        Anna's Decorations, Ltd  153996.13

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='SALES', y='CUSTOMERNAME', data=top_customers, palette='Greens')

# Set title and labels
plt.title('Top 10 High-Value Customers Based on Total Sales', fontsize=14)
plt.xlabel('Sales', fontsize=12)
plt.ylabel('Customer Name', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\krupa\AppData\Local\Temp\ipykernel_19372\264003692.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='SALES', y='CUSTOMERNAME', data=top_customers, palette='Greens')

# %%
customer_sales = df.groupby('CUSTOMERNAME').agg(
    total_sales=('SALES', 'sum'),
    total_orders=('ORDERLINENUMBER', 'nunique')  # Count the unique number of orders
).reset_index()

# Calculate average order value (AOV) for each customer
customer_sales['AOV'] = customer_sales['total_sales'] / customer_sales['total_orders']

# Ensure that AOV was calculated correctly
print(customer_sales.head())
# Out:
#               CUSTOMERNAME  total_sales  total_orders           AOV
# 0           AV Stores, Co.    157807.81            18   8767.100556
# 1             Alpha Cognac     70488.44            12   5874.036667
# 2       Amica Models & Co.     94117.26            17   5536.309412
# 3  Anna's Decorations, Ltd    153996.13            14  10999.723571
# 4        Atelier graphique     24179.96             4   6044.990000

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='AOV', y='CUSTOMERNAME', data=customer_sales.head(), palette='twilight_shifted')

plt.title('Average Order Value (AOV) for Each Customer', fontsize=14)
plt.xlabel('Average Order Value (AOV)', fontsize=12)
plt.ylabel('Customer Name', fontsize=12)

plt.show()
# Out:
# C:\Users\krupa\AppData\Local\Temp\ipykernel_19372\2348989922.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='AOV', y='CUSTOMERNAME', data=customer_sales.head(), palette='twilight_shifted')
